# %% [markdown]
# #Tested Fruitdata Model

# %%
test_dir=r'/content/drive/MyDrive/fruit-dataset/fruit-dataset/test'

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
model = tf.keras.models.load_model(r'/content/fruitdata.h5')

# %%
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical')
# Out:
# Found 1696 images belonging to 6 classes.

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
img=image.load_img(r"/content/1ec5d93e-76ab-44cf-a53e-ef3f741a095a___RS_HL 7504.JPG")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7F7D8AB2C110>

# %%
img=image.load_img(r"/content/1ec5d93e-76ab-44cf-a53e-ef3f741a095a___RS_HL 7504.JPG",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Apple___Black_rot', 'Apple___healthy', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Peach___Bacterial_spot', 'Peach___healthy']
index[y[0]]
# Out:
# 1/1 [==============================] - 0s 78ms/step
# 'Apple___healthy'

# %%
model.evaluate(test_generator_1,steps=50)
# Out:
# 50/50 [==============================] - 6s 113ms/step - loss: 442.5220 - accuracy: 0.6950
# [442.52203369140625, 0.6949999928474426]
